# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/result data/merged v5.csv')
df
# Out:
#        년도     팀        영문국가명  예선_승률   예선_골득실률  순위  승점  AvgApps   평균나이  \
# 0    2002   브라질       Brazil   0.46  2.352113   1  21  0.26087  26.74
# 1    2002    독일      Germany   0.55  1.817073   2  16  0.21739  28.26
# 2    2002    터키       Turkey   0.46  1.457627   3  13  0.00000  28.26
# 3    2002  대한민국  South Korea   0.48  2.216667   4  11  0.43478  27.13
# 4    2002   스페인        Spain   0.65  3.227273   5  11  0.26087  27.13
# ..    ...   ...          ...    ...       ...  ..  ..      ...    ...
# 187  2022   덴마크      Denmark   0.61  2.446429  28   1  0.46154  27.23
# 188  2022  세르비아       Serbia   0.48  1.536232  29   1  0.46154  26.92
# 189  2022   웨일스        Wales   0.44  1.233333  30   1  0.00000  26.54
# 190  2022   캐나다       Canada   0.48  2.296875  31   0  0.00000  27.08
# 191  2022   카타르        Qatar   0.49  1.388889  32   0  0.00000  27.12
#
#      top20소속선수수  ...  finishing     gk  passing  defending   rank  \
# ...

# %%
len(df.columns)
# Out:
# 31

# %%
df.columns
# Out:
# Index(['년도', '팀', '영문국가명', '예선_승률', '예선_골득실률', '순위', '승점', 'AvgApps', '평균나이',
#        'top20소속선수수', 'current_rating', 'ball_control', 'dribbling',
#        'composure', 'reaction', 'crossing', 'acceleration', 'stamina',
#        'strength', 'shot_power', 'sprint_speed', 'finishing', 'gk', 'passing',
#        'defending', 'rank', 'total_points', 'rank_diff', 'points_diff',
#        'attack_index', 'defense_index'],
#       dtype='object')

# %%
new_cols = ['Year', 'Nation', 'Eng_Nation', 'Q_WR', 'Q_GR', 'Wc_Rank', 'Wc_Point',
            'Avg_Apps', 'Avg_Age', 'Avg_Famous', 'FS_0', 'FS_1', 'FS_2', 'FS_3', 'FS_4', 
            'FS_5', 'FS_6', 'FS_7', 'FS_8', 'FS_9', 'FS_10', 'FS_14','FS_11', 'FS_12', 'FS_13',
            'F_Rank', 'F_Point', 'F_Rd', 'F_Pd','ATK_INDEX','DEF_INDEX']
df.columns = new_cols
df.iloc[0]
# Out:
# Year              2002
# Nation             브라질
# Eng_Nation      Brazil
# Q_WR              0.46
# Q_GR          2.352113
# Wc_Rank              1
# Wc_Point            21
# Avg_Apps       0.26087
# Avg_Age          26.74
# Avg_Famous           3
# FS_0             79.14
# FS_1             74.36
# FS_2             73.68
# FS_3             77.73
# FS_4             73.41
# FS_5             71.64
# FS_6             67.95
# FS_7             75.27
# FS_8             77.05
# FS_9             72.73
# FS_10            82.09
# FS_14            62.32
# FS_11            31.95
# FS_12            68.95
# FS_13            59.61
# F_Rank            1.33
# F_Point         818.33
# F_Rd               0.0
# F_Pd               0.0
# ATK_INDEX       0.1415
# DEF_INDEX    -0.070093
# Name: 0, dtype: object

# %%
new_cols = ['Year', 'Nation', 'Eng_Nation', 'Wc_Rank', 'Wc_Point', 'Q_WR', 'Q_GR', 
            'F_Rank', 'F_Point', 'F_Rd', 'F_Pd', 'Avg_Apps', 'Avg_Age', 'Avg_Famous', 'FS_0', 'FS_1', 'FS_2', 'FS_3', 'FS_4',
            'FS_5', 'FS_6', 'FS_7', 'FS_8', 'FS_9', 'FS_10', 'FS_11', 'FS_12', 'FS_13', 'FS_14','ATK_INDEX','DEF_INDEX']
df = df[new_cols]
df.columns
# Out:
# Index(['Year', 'Nation', 'Eng_Nation', 'Wc_Rank', 'Wc_Point', 'Q_WR', 'Q_GR',
#        'F_Rank', 'F_Point', 'F_Rd', 'F_Pd', 'Avg_Apps', 'Avg_Age',
#        'Avg_Famous', 'FS_0', 'FS_1', 'FS_2', 'FS_3', 'FS_4', 'FS_5', 'FS_6',
#        'FS_7', 'FS_8', 'FS_9', 'FS_10', 'FS_11', 'FS_12', 'FS_13', 'FS_14',
#        'ATK_INDEX', 'DEF_INDEX'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 31

# %%
df.columns
# Out:
# Index(['Year', 'Nation', 'Eng_Nation', 'Wc_Rank', 'Wc_Point', 'Q_WR', 'Q_GR',
#        'F_Rank', 'F_Point', 'F_Rd', 'F_Pd', 'Avg_Apps', 'Avg_Age',
#        'Avg_Famous', 'FS_0', 'FS_1', 'FS_2', 'FS_3', 'FS_4', 'FS_5', 'FS_6',
#        'FS_7', 'FS_8', 'FS_9', 'FS_10', 'FS_11', 'FS_12', 'FS_13', 'FS_14',
#        'ATK_INDEX', 'DEF_INDEX'],
#       dtype='object')

# %%
df.to_csv('../data/result data/Final DF.csv',index=False,encoding='utf-8')
